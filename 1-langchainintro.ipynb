# %% [markdown]
# ### langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os
from dotenv import  load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# #### Generative AI Application using Agenyts and OpenAI model
